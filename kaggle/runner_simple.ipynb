# %% [markdown]
# # EEGTokenizer Kaggle 实验 Runner（简化版）
#
# 此 Notebook 用于从 GitHub pull 代码，运行实验，**不 push 结果回 GitHub**（先跑通看看）。
#
# ## 前置条件
# 1. 数据集已上传到 Kaggle Dataset

# %%
# ========== 1. 配置 ==========
import os
from pathlib import Path

# GitHub 配置（使用 HTTPS，不需要 SSH key）
GITHUB_REPO = "https://github.com/KyleCream/EEGTokenizer.git"
GITHUB_BRANCH = "main"

# Kaggle 数据集路径（老板你上传的数据集路径）
DATASET_PATH = "/kaggle/input/eeg-dataset"

# 工作目录
WORK_DIR = Path("/kaggle/working/EEGTokenizer")

print(f"工作目录: {WORK_DIR}")
print(f"数据集路径: {DATASET_PATH}")

# %%
# ========== 2. 从 GitHub Pull 最新代码 ==========
# 配置 git 避免交互式确认
# !git config --global user.name "Kaggle Bot"
# !git config --global user.email "kaggle@example.com"
# !git config --global pull.rebase false
# !git config --global core.askpass ""
# !git config --global credential.helper "store"

# Clone or pull
# !cd /kaggle/working && rm -rf EEGTokenizer && git clone {GITHUB_REPO} -q
# !cd {WORK_DIR} && git checkout {GITHUB_BRANCH} -q && git pull origin {GITHUB_BRANCH} -q

print("\n✅ 代码拉取完成！")

# %%
# ========== 3. 安装依赖 ==========
# !cd {WORK_DIR} && pip install -q -r requirements.txt
print("\n✅ 依赖安装完成！")

# %%
# ========== 4. 运行实验 ==========
# !cd {WORK_DIR} && python kaggle/run_experiment.py

# %% [markdown]
# ## 完成！
#
# 实验结果保存在 `/kaggle/working/EEGTokenizer/kaggle/results/` 目录下。
#
# 老板你可以：
# 1. 在 Kaggle 右侧 "Output" 栏下载结果
# 2. 或者手动把结果文件上传回 GitHub
