# %% [markdown]
# # EEGTokenizer Kaggle 实验 Runner
#
# 此 Notebook 用于从 GitHub pull 代码，运行实验，并将结果 push 回 GitHub。
#
# ## 前置条件
# 1. 数据集已上传到 Kaggle Dataset
# 2. GitHub API Key 已配置（用于 push 结果）

# %%
# ========== 1. 配置 ==========
import os
from pathlib import Path

# GitHub 配置
GITHUB_REPO = "git@github.com:KyleCream/EEGTokenizer.git"  # 或使用 HTTPS
GITHUB_BRANCH = "main"

# Kaggle 数据集路径
DATASET_PATH = "/kaggle/input/eeg-dataset"  # 老板你上传的数据集路径

# 工作目录
WORK_DIR = Path("/kaggle/working/EEGTokenizer")

print(f"工作目录: {WORK_DIR}")
print(f"数据集路径: {DATASET_PATH}")

# %%
# ========== 2. 从 GitHub Pull 最新代码 ==========
# !cd /kaggle/working && git clone {GITHUB_REPO} || true
# !cd {WORK_DIR} && git checkout {GITHUB_BRANCH} && git pull origin {GITHUB_BRANCH}

# %%
# ========== 3. 安装依赖 ==========
# !cd {WORK_DIR} && pip install -r requirements.txt

# %%
# ========== 4. 运行实验 ==========
# !cd {WORK_DIR} && python kaggle/run_experiment.py

# %%
# ========== 5. Push 结果回 GitHub ==========
# 配置 git 用户（首次运行需要）
# !cd {WORK_DIR} && git config user.name "Kaggle Bot" && git config user.email "kaggle@example.com"

# 运行 push 脚本
# !cd {WORK_DIR} && python kaggle/push_results.py

# %% [markdown]
# ## 完成！
#
# 实验结果已推送到 GitHub 的 `kaggle/results/` 目录下。
